# %% [markdown]
# # EDA On Biometric Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing biometric file 1

# %%
demo_1=pd.read_csv('api_data_aadhar_biometric_0_500000.csv')
demo_1
# Out:
#               date              state      district  pincode  bio_age_5_17  \
# 0       01-03-2025            Haryana  Mahendragarh   123029           280
# 1       01-03-2025              Bihar     Madhepura   852121           144
# 2       01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3       01-03-2025              Bihar       Bhojpur   802158           256
# 4       01-03-2025         Tamil Nadu       Madurai   625514           271
# ...            ...                ...           ...      ...           ...
# 499995  19-09-2025              Delhi    West Delhi   110041           102
# 499996  19-09-2025              Delhi    West Delhi   110043             8
# 499997  19-09-2025              Delhi    West Delhi   110058             7
# 499998  19-09-2025                Goa     North Goa   403102             1
# 499999  19-09-2025                Goa     North Goa   403106             1
#
#         bio_age_17_
# 0               577
# 1               369
# 2              1091
# 3               980
# 4               815
# ...             ...
# 499995          100
# 499996            5
# 499997            5
# 499998            0
# 499999            0
#
# [500000 rows x 6 columns]

# %%
demo_1.shape
# Out:
# (500000, 6)

# %%
demo_1['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
#        'Uttaranchal', 'Chhatisgarh'], dtype=object)

# %%
demo_1['state'].nunique()
# Out:
# 56

# %%
demo_1['new_date'] = pd.to_datetime(
    demo_1['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_1
# Out:
#               date              state      district  pincode  bio_age_5_17  \
# 0       01-03-2025            Haryana  Mahendragarh   123029           280
# 1       01-03-2025              Bihar     Madhepura   852121           144
# 2       01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3       01-03-2025              Bihar       Bhojpur   802158           256
# 4       01-03-2025         Tamil Nadu       Madurai   625514           271
# ...            ...                ...           ...      ...           ...
# 499995  19-09-2025              Delhi    West Delhi   110041           102
# 499996  19-09-2025              Delhi    West Delhi   110043             8
# 499997  19-09-2025              Delhi    West Delhi   110058             7
# 499998  19-09-2025                Goa     North Goa   403102             1
# 499999  19-09-2025                Goa     North Goa   403106             1
#
#         bio_age_17_  new_date
# 0               577  20250301
# 1               369  20250301
# 2              1091  20250301
# 3               980  20250301
# 4               815  20250301
# ...             ...       ...
# 499995          100  20250919
# 499996            5  20250919
# 499997            5  20250919
# 499998            0  20250919
# 499999            0  20250919
#
# [500000 rows x 7 columns]

# %%
demo_1['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_1['new_date'].max())
print(demo_1['new_date'].min())
# Out:
# 20250919
# 20250301

# %% [markdown]
# ## Importing biometric file 2

# %%
demo_2=pd.read_csv('api_data_aadhar_biometric_500000_1000000.csv')
demo_2.head()
# Out:
#          date state   district  pincode  bio_age_5_17  bio_age_17_
# 0  19-09-2025   Goa  North Goa   403502             0            4
# 1  19-09-2025   Goa  North Goa   403508             1            4
# 2  19-09-2025   Goa  North Goa   403513             2            0
# 3  19-09-2025   Goa  North Goa   403527             2            2
# 4  19-09-2025   Goa  South Goa   403601             7            3

# %%
demo_2.shape
# Out:
# (500000, 6)

# %%
demo_2['state'].unique()
# Out:
# array(['Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman & Diu', 'Delhi',
#        'Daman and Diu', 'West  Bengal',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Dadra & Nagar Haveli',
#        'West bengal', 'West Bangal', 'ODISHA', 'WEST BENGAL',
#        'andhra pradesh', 'odisha', 'Westbengal', 'WESTBENGAL'],
#       dtype=object)

# %%
demo_2['state'].nunique()
# Out:
# 53

# %%
demo_2['new_date'] = pd.to_datetime(
    demo_2['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_2
# Out:
#               date   state   district  pincode  bio_age_5_17  bio_age_17_  \
# 0       19-09-2025     Goa  North Goa   403502             0            4
# 1       19-09-2025     Goa  North Goa   403508             1            4
# 2       19-09-2025     Goa  North Goa   403513             2            0
# 3       19-09-2025     Goa  North Goa   403527             2            2
# 4       19-09-2025     Goa  South Goa   403601             7            3
# ...            ...     ...        ...      ...           ...          ...
# 499995  07-11-2025  Kerala  Ernakulam   682020             1            6
# 499996  07-11-2025  Kerala  Ernakulam   682022             1            0
# 499997  07-11-2025  Kerala  Ernakulam   682023             0            1
# 499998  07-11-2025  Kerala  Ernakulam   682025             3            6
# 499999  07-11-2025  Kerala  Ernakulam   682026             1            3
#
#         new_date
# 0       20250919
# 1       20250919
# 2       20250919
# 3       20250919
# 4       20250919
# ...          ...
# 499995  20251107
# 499996  20251107
# 499997  20251107
# 499998  20251107
# 499999  20251107
#
# [500000 rows x 7 columns]

# %%
demo_2['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_2['new_date'].max())
print(demo_2['new_date'].min())
# Out:
# 20251107
# 20250919

# %% [markdown]
# ## Importing Biometric file 3

# %%
demo_3=pd.read_csv('api_data_aadhar_biometric_1000000_1500000.csv')
demo_3.head()
# Out:
#          date             state      district  pincode  bio_age_5_17  \
# 0  07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1  07-11-2025           Haryana   Yamunanagar   135001             1
# 2  07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3  07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4  07-11-2025  Himachal Pradesh      Bilaspur   174013             3
#
#    bio_age_17_
# 0            6
# 1            2
# 2            2
# 3            0
# 4            1

# %%
demo_3.shape
# Out:
# (500000, 6)

# %%
demo_3['state'].unique()
# Out:
# array(['Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Jammu & Kashmir',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Ladakh', 'West Bangal',
#        'West bengal', 'odisha',
#        'Dadra and Nagar Haveli and Daman and Diu', 'West  Bengal',
#        'WEST BENGAL', 'andhra pradesh', 'Westbengal', 'Chhatisgarh',
#        'ODISHA', 'WESTBENGAL', 'Uttaranchal'], dtype=object)

# %%
demo_3['state'].nunique()
# Out:
# 55

# %%
demo_3['new_date'] = pd.to_datetime(
    demo_3['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_3
# Out:
#               date             state      district  pincode  bio_age_5_17  \
# 0       07-11-2025           Haryana  Yamuna Nagar   135002             4
# 1       07-11-2025           Haryana   Yamunanagar   135001             1
# 2       07-11-2025  Himachal Pradesh      Bilaspur   174004             2
# 3       07-11-2025  Himachal Pradesh      Bilaspur   174005             1
# 4       07-11-2025  Himachal Pradesh      Bilaspur   174013             3
# ...            ...               ...           ...      ...           ...
# 499995  08-12-2025           Gujarat      Vadodara   391150             3
# 499996  08-12-2025           Gujarat      Vadodara   391168            11
# 499997  08-12-2025           Gujarat      Vadodara   391170             0
# 499998  08-12-2025           Gujarat      Vadodara   391410             9
# 499999  08-12-2025           Gujarat      Vadodara   391530             3
#
#         bio_age_17_  new_date
# 0                 6  20251107
# 1                 2  20251107
# 2                 2  20251107
# 3                 0  20251107
# 4                 1  20251107
# ...             ...       ...
# 499995           18  20251208
# 499996           34  20251208
# 499997           23  20251208
# 499998            4  20251208
# 499999            7  20251208
#
# [500000 rows x 7 columns]

# %%
demo_3['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_3['new_date'].max())
print(demo_3['new_date'].min())
# Out:
# 20251208
# 20251107

# %% [markdown]
# ## Importing Biometric file 4

# %%
demo_4=pd.read_csv('api_data_aadhar_biometric_1500000_1861108.csv')
demo_4.head()
# Out:
#          date          state       district  pincode  bio_age_5_17  \
# 0  08-12-2025  Uttar Pradesh      Moradabad   244411             4
# 1  08-12-2025  Uttar Pradesh      Moradabad   244601            14
# 2  08-12-2025  Uttar Pradesh  Muzaffarnagar   251002            22
# 3  08-12-2025  Uttar Pradesh  Muzaffarnagar   251202             4
# 4  08-12-2025  Uttar Pradesh  Muzaffarnagar   251319             4
#
#    bio_age_17_
# 0            2
# 1           19
# 2           37
# 3            4
# 4            7

# %%
demo_4.shape
# Out:
# (361108, 6)

# %%
demo_4['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Uttarakhand', 'West Bangal', 'West Bengal',
#        'West bengal', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Jharkhand', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'Andhra Pradesh', 'Arunachal Pradesh', 'Dadra & Nagar Haveli',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Tripura',
#        'Daman and Diu', 'Jammu & Kashmir', 'Daman & Diu', 'WEST BENGAL',
#        'ODISHA', 'Chhatisgarh', 'Westbengal', 'West  Bengal', 'Tamilnadu',
#        'andhra pradesh'], dtype=object)

# %%
demo_4['state'].nunique()
# Out:
# 53

# %%
demo_4['new_date'] = pd.to_datetime(
    demo_4['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_4
# Out:
#               date          state        district  pincode  bio_age_5_17  \
# 0       08-12-2025  Uttar Pradesh       Moradabad   244411             4
# 1       08-12-2025  Uttar Pradesh       Moradabad   244601            14
# 2       08-12-2025  Uttar Pradesh   Muzaffarnagar   251002            22
# 3       08-12-2025  Uttar Pradesh   Muzaffarnagar   251202             4
# 4       08-12-2025  Uttar Pradesh   Muzaffarnagar   251319             4
# ...            ...            ...             ...      ...           ...
# 361103  29-12-2025    West Bengal  Uttar Dinajpur   733201             4
# 361104  29-12-2025    West Bengal  Uttar Dinajpur   733213             0
# 361105  29-12-2025    West Bengal  West Midnapore   721304             0
# 361106  29-12-2025    West Bengal  West Midnapore   721451             2
# 361107  29-12-2025    West Bengal  West Midnapore   721457             0
#
#         bio_age_17_  new_date
# 0                 2  20251208
# 1                19  20251208
# 2                37  20251208
# 3                 4  20251208
# 4                 7  20251208
# ...             ...       ...
# 361103            9  20251229
# 361104            1  20251229
# 361105            3  20251229
# 361106            0  20251229
# 361107            1  20251229
#
# [361108 rows x 7 columns]

# %%
demo_4['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_4['new_date'].max())
print(demo_4['new_date'].min())
# Out:
# 20251229
# 20251208

# %% [markdown]
# ## Merging four datasets

# %%
df = pd.concat([demo_1, demo_2, demo_3, demo_4], axis=0, ignore_index=True)
df.shape
# Out:
# (1861108, 7)

# %%
df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_  new_date
# 0          577  20250301
# 1          369  20250301
# 2         1091  20250301
# 3          980  20250301
# 4          815  20250301

# %%
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['state'].nunique()
# Out:
# 57

# %%
df['state'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Orissa',
#        'Puducherry', 'Pondicherry', 'Manipur', 'Sikkim', 'Tripura',
#        'Mizoram', 'Arunachal Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Andaman and Nicobar Islands', 'Andaman & Nicobar Islands',
#        'Dadra and Nagar Haveli', 'Lakshadweep', 'Daman & Diu',
#        'Dadra & Nagar Haveli', 'Jammu & Kashmir', 'WESTBENGAL',
#        'andhra pradesh', 'Westbengal', 'West  Bengal', 'WEST BENGAL',
#        'West Bangal', 'ODISHA', 'odisha', 'West bengal', 'west Bengal',
#        'Uttaranchal', 'Chhatisgarh', 'Tamilnadu'], dtype=object)

# %%
df[df['state']=='Uttaranchal']
# Out:
#                date        state district  pincode  bio_age_5_17  bio_age_17_  \
# 374898   13-09-2025  Uttaranchal   Almora   263601             0            1
# 1431510  05-12-2025  Uttaranchal  Garhwal   249302             0            1
#
#          new_date
# 374898   20250913
# 1431510  20251205

# %%
df[df['state']=='Tamilnadu']
# Out:
#                date      state district  pincode  bio_age_5_17  bio_age_17_  \
# 1810261  27-12-2025  Tamilnadu  Chennai   600094             1            0
#
#          new_date
# 1810261  20251227

# %% [markdown]
# ### Mapping state with correct name

# %%
df['state'] = df['state'].replace('Uttaranchal', 'Uttarakhand')

# %%
df['state'] = df['state'].replace('Tamilnadu', 'Tamil Nadu')

# %% [markdown]
# ## Mapping state names

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {
    # West Bengal
    'west bengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal ': 'West Bengal',
    'west bengli':  'West Bengal',
    

    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Collapse all Dadra / Daman variants into ONE state
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',


    # Puducherry
    'puducherry': 'Puducherry',


    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Puducherry
    'pondicherry': 'Puducherry',

    # Case-normalized direct matches
    'delhi': 'Delhi',
    'ladakh': 'Ladakh',
    'goa': 'Goa',
    'sikkim': 'Sikkim',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'punjab': 'Punjab',
    'kerala': 'Kerala',
    'haryana': 'Haryana',
    'gujarat': 'Gujarat',
    'tamil nadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'karnataka': 'Karnataka',
    'maharashtra': 'Maharashtra',
    'Nagpur': 'Maharashtra',
    'rajasthan': 'Rajasthan',
    'uttar pradesh': 'Uttar Pradesh',
    'madhya pradesh': 'Madhya Pradesh',
    'himachal pradesh': 'Himachal Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'chhattisgarh': 'Chhattisgarh',
    'chhatisgarh' : 'Chhattisgarh',
    'jharkhand': 'Jharkhand',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'tripura': 'Tripura',
    'uttarakhand': 'Uttarakhand',
    'lakshadweep': 'Lakshadweep',
    'chandigarh': 'Chandigarh'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: []

# %%
df['state_clean'].unique()
# Out:
# array(['Haryana', 'Bihar', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Maharashtra', 'Gujarat', 'Odisha', 'West Bengal', 'Kerala',
#        'Rajasthan', 'Punjab', 'Himachal Pradesh', 'Uttar Pradesh',
#        'Assam', 'Uttarakhand', 'Madhya Pradesh', 'Karnataka',
#        'Andhra Pradesh', 'Telangana', 'Goa', 'Nagaland', 'Jharkhand',
#        'Delhi', 'Chhattisgarh', 'Meghalaya', 'Chandigarh', 'Puducherry',
#        'Manipur', 'Sikkim', 'Tripura', 'Mizoram', 'Arunachal Pradesh',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Andaman and Nicobar Islands', 'Lakshadweep'], dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
df.head(20)
# Out:
#           date              state           district  pincode  bio_age_5_17  \
# 0   01-03-2025            Haryana       Mahendragarh   123029           280
# 1   01-03-2025              Bihar          Madhepura   852121           144
# 2   01-03-2025  Jammu and Kashmir              Punch   185101           643
# 3   01-03-2025              Bihar            Bhojpur   802158           256
# 4   01-03-2025         Tamil Nadu            Madurai   625514           271
# 5   01-03-2025        Maharashtra          Ratnagiri   416702           155
# 6   01-03-2025            Gujarat              Anand   388130            75
# 7   01-03-2025            Gujarat        Gandhinagar   382421           192
# 8   01-03-2025             Odisha          Dhenkanal   759025           122
# 9   01-03-2025            Gujarat             Valsad   396055            67
# 10  01-03-2025         Tamil Nadu              Salem   636119           103
# 11  01-03-2025        West Bengal            Hooghly   712414            91
# 12  01-03-2025        West Bengal  Paschim Medinipur   721147            86
# 13  01-03-2025             Kerala            Wayanad   670721            75
# 14  01-03-2025          Rajasthan     Sawai Madhopur   322027           108
# 15  01-03-2025              Bihar           Vaishali   844504           426
# 16  01-03-2025         Tamil Nadu              Karur   639105           131
# 17  01-03-2025             Punjab           Rupnagar   140118            38
# 18  01-03-2025            Gujarat        Sabarkantha   383440            56
# 19  01-03-2025   Himachal Pradesh                Una   177039            24
#
#     bio_age_17_  new_date        state_clean
# 0           577  20250301            Haryana
# 1           369  20250301              Bihar
# 2          1091  20250301  Jammu and Kashmir
# 3           980  20250301              Bihar
# 4           815  20250301         Tamil Nadu
# 5           529  20250301        Maharashtra
# 6           143  20250301            Gujarat
# 7           298  20250301            Gujarat
# 8           214  20250301             Odisha
# 9            85  20250301            Gujarat
# 10           63  20250301         Tamil Nadu
# 11           97  20250301        West Bengal
# 12          116  20250301        West Bengal
# 13          293  20250301             Kerala
# 14          300  20250301          Rajasthan
# 15          958  20250301              Bihar
# 16          103  20250301         Tamil Nadu
# 17           97  20250301             Punjab
# 18           91  20250301            Gujarat
# 19           30  20250301   Himachal Pradesh

# %%
df.tail(20)
# Out:
#                date        state                    district  pincode  \
# 1861088  29-12-2025  West Bengal           South 24 Parganas   743375
# 1861089  29-12-2025  West Bengal           South 24 Parganas   743378
# 1861090  29-12-2025  West Bengal           South 24 Parganas   743384
# 1861091  29-12-2025  West Bengal           South 24 Parganas   743392
# 1861092  29-12-2025  West Bengal           South 24 Parganas   743502
# 1861093  29-12-2025  West Bengal              South Dinajpur   733126
# 1861094  29-12-2025  West Bengal              South Dinajpur   733140
# 1861095  29-12-2025  West Bengal              South Dinajpur   733145
# 1861096  29-12-2025  West Bengal              South Dinajpur   733153
# 1861097  29-12-2025  West Bengal              South Dinajpur   733155
# 1861098  29-12-2025  West Bengal  South Twenty Four Parganas   700084
# 1861099  29-12-2025  West Bengal  South Twenty Four Parganas   700145
# 1861100  29-12-2025  West Bengal  South Twenty Four Parganas   743348
# 1861101  29-12-2025  West Bengal  South Twenty Four Parganas   743370
# 1861102  29-12-2025  West Bengal  South Twenty Four Parganas   743373
# 1861103  29-12-2025  West Bengal              Uttar Dinajpur   733201
# 1861104  29-12-2025  West Bengal              Uttar Dinajpur   733213
# 1861105  29-12-2025  West Bengal              West Midnapore   721304
# 1861106  29-12-2025  West Bengal              West Midnapore   721451
# 1861107  29-12-2025  West Bengal              West Midnapore   721457
#
#          bio_age_5_17  bio_age_17_  new_date  state_clean
# 1861088             2            3  20251229  West Bengal
# 1861089             2            3  20251229  West Bengal
# 1861090             2            0  20251229  West Bengal
# 1861091             0            1  20251229  West Bengal
# 1861092             9            5  20251229  West Bengal
# 1861093             0            4  20251229  West Bengal
# 1861094             0            1  20251229  West Bengal
# 1861095             0            1  20251229  West Bengal
# 1861096             1            0  20251229  West Bengal
# 1861097             1            1  20251229  West Bengal
# 1861098             0            1  20251229  West Bengal
# 1861099             1            3  20251229  West Bengal
# 1861100             0            1  20251229  West Bengal
# 1861101             1            0  20251229  West Bengal
# 1861102             1            8  20251229  West Bengal
# 1861103             4            9  20251229  West Bengal
# 1861104             0            1  20251229  West Bengal
# 1861105             0            3  20251229  West Bengal
# 1861106             2            0  20251229  West Bengal
# 1861107             0            1  20251229  West Bengal

# %%
df.dtypes
# Out:
# date            object
# state           object
# district        object
# pincode          int64
# bio_age_5_17     int64
# bio_age_17_      int64
# new_date        object
# state_clean     object
# dtype: object

# %%
df
# Out:
#                date              state        district  pincode  bio_age_5_17  \
# 0        01-03-2025            Haryana    Mahendragarh   123029           280
# 1        01-03-2025              Bihar       Madhepura   852121           144
# 2        01-03-2025  Jammu and Kashmir           Punch   185101           643
# 3        01-03-2025              Bihar         Bhojpur   802158           256
# 4        01-03-2025         Tamil Nadu         Madurai   625514           271
# ...             ...                ...             ...      ...           ...
# 1861103  29-12-2025        West Bengal  Uttar Dinajpur   733201             4
# 1861104  29-12-2025        West Bengal  Uttar Dinajpur   733213             0
# 1861105  29-12-2025        West Bengal  West Midnapore   721304             0
# 1861106  29-12-2025        West Bengal  West Midnapore   721451             2
# 1861107  29-12-2025        West Bengal  West Midnapore   721457             0
#
#          bio_age_17_  new_date        state_clean
# 0                577  20250301            Haryana
# 1                369  20250301              Bihar
# 2               1091  20250301  Jammu and Kashmir
# 3                980  20250301              Bihar
# 4                815  20250301         Tamil Nadu
# ...              ...       ...                ...
# 1861103            9  20251229        West Bengal
# 1861104            1  20251229        West Bengal
# 1861105            3  20251229        West Bengal
# 1861106            0  20251229        West Bengal
# 1861107            1  20251229        West Bengal
#
# [1861108 rows x 8 columns]

# %% [markdown]
# ### Filtering data on state (Maharashtra)

# %%
df_maharashtra=df[df['state_clean']=='Maharashtra'].copy()
df_maharashtra
# Out:
#                date        state    district  pincode  bio_age_5_17  \
# 5        01-03-2025  Maharashtra   Ratnagiri   416702           155
# 27       01-03-2025  Maharashtra      Wardha   442101           269
# 106      01-03-2025  Maharashtra    Amravati   444801           291
# 117      01-03-2025  Maharashtra       Dhule   424308           103
# 120      01-03-2025  Maharashtra   Ratnagiri   415606            47
# ...             ...          ...         ...      ...           ...
# 1860382  29-12-2025  Maharashtra    Amravati   444905             6
# 1860383  29-12-2025  Maharashtra  Aurangabad   431001           101
# 1860384  29-12-2025  Maharashtra  Aurangabad   431005             2
# 1860385  29-12-2025  Maharashtra  Aurangabad   431105            11
# 1860386  29-12-2025  Maharashtra  Aurangabad   431107             5
#
#          bio_age_17_  new_date  state_clean
# 5                529  20250301  Maharashtra
# 27               538  20250301  Maharashtra
# 106             1013  20250301  Maharashtra
# 117              355  20250301  Maharashtra
# 120              182  20250301  Maharashtra
# ...              ...       ...          ...
# 1860382            7  20251229  Maharashtra
# 1860383          198  20251229  Maharashtra
# 1860384           14  20251229  Maharashtra
# 1860385           18  20251229  Maharashtra
# 1860386           10  20251229  Maharashtra
#
# [151104 rows x 8 columns]

# %%
df_maharashtra['district'].unique()
# Out:
# array(['Ratnagiri', 'Wardha', 'Amravati', 'Dhule', 'Ahmadnagar', 'Nagpur',
#        'Solapur', 'Kolhapur', 'Chandrapur', 'Nanded', 'Mumbai Suburban',
#        'Nashik', 'Gadchiroli', 'Nandurbar', 'Palghar', 'Parbhani',
#        'Yavatmal', 'Satara', 'Pune', 'Gondiya', 'Sangli', 'Thane',
#        'Raigarh', 'Bhandara', 'Akola', 'Sindhudurg', 'Hingoli', 'Beed',
#        'Jalna', 'Aurangabad', 'Jalgaon', 'Mumbai', 'Latur', 'Buldana',
#        'Buldhana', 'Mumbai City', 'Raigad', 'Osmanabad',
#        'Chhatrapati Sambhajinagar', 'Washim', 'Bid',
#        'Chatrapati Sambhaji Nagar', 'Ahmed Nagar', 'Dharashiv',
#        'Mumbai( Sub Urban )', 'Gondia', 'Gondiya *', 'Nandurbar *',
#        'Raigarh(MH)', 'Washim *', 'Hingoli *', 'Ahilyanagar'],
#       dtype=object)

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
district_mapping_maharashtra = {

    # Ahmednagar (Ahilyanagar)
    'ahmadnagar': 'Ahmednagar',
    'ahmed nagar': 'Ahmednagar',
    'ahilyanagar': 'Ahmednagar',

    # Akola
    'akola': 'Akola',

    # Amravati
    'amravati': 'Amravati',

    # Aurangabad → Chhatrapati Sambhajinagar
    'aurangabad': 'Chhatrapati Sambhajinagar',
    'chhatrapati sambhajinagar': 'Chhatrapati Sambhajinagar',
    'chatrapati sambhaji nagar': 'Chhatrapati Sambhajinagar',

    # Beed
    'beed': 'Beed',
    'bid': 'Beed',

    # Bhandara
    'bhandara': 'Bhandara',

    # Buldhana
    'buldhana': 'Buldhana',
    'buldana': 'Buldhana',

    # Chandrapur
    'chandrapur': 'Chandrapur',

    # Dharashiv (Osmanabad)
    'osmanabad': 'Dharashiv',
    'dharashiv': 'Dharashiv',

    # Dhule
    'dhule': 'Dhule',

    # Gadchiroli
    'gadchiroli': 'Gadchiroli',

    # Gondia
    'gondia': 'Gondia',
    'gondiya': 'Gondia',
    'gondiya *': 'Gondia',

    # Hingoli
    'hingoli': 'Hingoli',
    'hingoli *': 'Hingoli',

    # Jalgaon
    'jalgaon': 'Jalgaon',

    # Jalna
    'jalna': 'Jalna',

    # Kolhapur
    'kolhapur': 'Kolhapur',

    # Latur
    'latur': 'Latur',

    # Mumbai
    'mumbai': 'Mumbai',
    'mumbai city': 'Mumbai',
    'mumbai suburban': 'Mumbai Suburban',
    'mumbai sub urban': 'Mumbai Suburban',
    'mumbai( sub urban )': 'Mumbai Suburban',

    # Nagpur
    'nagpur': 'Nagpur',

    # Nanded
    'nanded': 'Nanded',

    # Nandurbar
    'nandurbar': 'Nandurbar',
    'nandurbar *': 'Nandurbar',

    # Nashik
    'nashik': 'Nashik',

    # Palghar
    'palghar': 'Palghar',

    # Parbhani
    'parbhani': 'Parbhani',

    # Pune
    'pune': 'Pune',

    # Raigad
    'raigad': 'Raigad',
    'raigarh': 'Raigad',
    'raigarh mh': 'Raigad',

    # Ratnagiri
    'ratnagiri': 'Ratnagiri',

    # Sangli
    'sangli': 'Sangli',

    # Satara
    'satara': 'Satara',

    # Sindhudurg
    'sindhudurg': 'Sindhudurg',

    # Solapur
    'solapur': 'Solapur',

    # Thane
    'thane': 'Thane',

    # Wardha
    'wardha': 'Wardha',

    # Washim
    'washim': 'Washim',
    'washim *': 'Washim',

    # Yavatmal
    'yavatmal': 'Yavatmal'
}

# %%
df_maharashtra['district_clean'] = (
    df_maharashtra['district']
    .apply(clean_name)
    .map(district_mapping_maharashtra)
    .fillna(df_maharashtra['district'])
)

# %%
# Remaining unmappped
df_maharashtra[df_maharashtra['district_clean'].isna()]['district'].unique()

# count check
df_maharashtra['district_clean'].nunique()
# Out:
# 36

# %%
df_maharashtra
# Out:
#                date        state    district  pincode  bio_age_5_17  \
# 5        01-03-2025  Maharashtra   Ratnagiri   416702           155
# 27       01-03-2025  Maharashtra      Wardha   442101           269
# 106      01-03-2025  Maharashtra    Amravati   444801           291
# 117      01-03-2025  Maharashtra       Dhule   424308           103
# 120      01-03-2025  Maharashtra   Ratnagiri   415606            47
# ...             ...          ...         ...      ...           ...
# 1860382  29-12-2025  Maharashtra    Amravati   444905             6
# 1860383  29-12-2025  Maharashtra  Aurangabad   431001           101
# 1860384  29-12-2025  Maharashtra  Aurangabad   431005             2
# 1860385  29-12-2025  Maharashtra  Aurangabad   431105            11
# 1860386  29-12-2025  Maharashtra  Aurangabad   431107             5
#
#          bio_age_17_  new_date  state_clean             district_clean
# 5                529  20250301  Maharashtra                  Ratnagiri
# 27               538  20250301  Maharashtra                     Wardha
# 106             1013  20250301  Maharashtra                   Amravati
# 117              355  20250301  Maharashtra                      Dhule
# 120              182  20250301  Maharashtra                  Ratnagiri
# ...              ...       ...          ...                        ...
# 1860382            7  20251229  Maharashtra                   Amravati
# 1860383          198  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860384           14  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860385           18  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860386           10  20251229  Maharashtra  Chhatrapati Sambhajinagar
#
# [151104 rows x 9 columns]

# %%
df_maharashtra['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_maharashtra['pincode'].nunique()
# Out:
# 1607

# %%
# df_maharashtra[['district_clean','pincode']].value_count().reset_index(name='count')

# %%
df_maharashtra[df_maharashtra['district_clean']== 'Thane']['pincode'].unique()
# Out:
# array([421004, 401102, 401106, 401606, 401303, 421101, 400705, 421311,
#        421203, 401305, 400614, 421502, 421204, 401209, 421302, 400601,
#        421605, 401107, 421306, 400709, 421201, 421401, 400610, 421202,
#        421102, 421505, 400602, 401204, 421103, 401504, 401208, 400710,
#        401105, 400708, 401207, 400612, 400605, 400603, 421603, 400703,
#        421005, 400606, 401607, 421402, 400701, 401201, 401404, 421602,
#        400615, 421002, 401202, 401203, 421501, 400607, 400706, 421308,
#        400608, 400604, 421403, 401101, 401602, 421503, 421001, 421305,
#        421601, 421301, 401301, 401501, 401304, 421506, 421303, 421312,
#        401605, 401604, 421003, 401206, 401403, 401302, 401402, 401603,
#        421604, 421304, 401103, 401701, 401601, 401702, 401503, 401703,
#        401104, 401610, 401405, 401502, 401506, 401609, 401401, 401608])

# %%
pin_district_count = (
    df_maharashtra.groupby('pincode')['district_clean']
    .nunique()
    .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#       pincode  district_count
# 0      400001               2
# 1      400002               1
# 2      400003               2
# 3      400004               1
# 4      400005               1
# ...       ...             ...
# 1602   445307               1
# 1603   445308               1
# 1604   445323               1
# 1605   445401               1
# 1606   445402               1
#
# [1607 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#       pincode  district_count
# 0      400001               2
# 2      400003               2
# 8      400009               2
# 11     400012               3
# 23     400024               2
# ...       ...             ...
# 1520   444407               2
# 1522   444501               2
# 1523   444502               2
# 1524   444503               2
# 1554   444802               2
#
# [193 rows x 2 columns]

# %%
df_flagged = df_maharashtra.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#              date        state         district  pincode  bio_age_5_17  \
# 0      01-03-2025  Maharashtra  Mumbai Suburban   400052            58
# 1      01-03-2025  Maharashtra          Palghar   401601            88
# 2      01-03-2025  Maharashtra            Akola   444407           105
# 3      01-03-2025  Maharashtra           Nagpur   441106           656
# 4      01-03-2025  Maharashtra            Jalna   431007            23
# ...           ...          ...              ...      ...           ...
# 29314  29-12-2025  Maharashtra           Washim   444107             1
# 29315  29-12-2025  Maharashtra           Washim   444403            54
# 29316  29-12-2025  Maharashtra            Akola   444502             3
# 29317  29-12-2025  Maharashtra         Amravati   442302             0
# 29318  29-12-2025  Maharashtra       Aurangabad   431105            11
#
#        bio_age_17_  new_date  state_clean             district_clean
# 0               68  20250301  Maharashtra            Mumbai Suburban
# 1               65  20250301  Maharashtra                    Palghar
# 2              578  20250301  Maharashtra                      Akola
# 3             1503  20250301  Maharashtra                     Nagpur
# 4               30  20250301  Maharashtra                      Jalna
# ...            ...       ...          ...                        ...
# 29314            7  20251229  Maharashtra                     Washim
# 29315           46  20251229  Maharashtra                     Washim
# 29316            7  20251229  Maharashtra                      Akola
# 29317            2  20251229  Maharashtra                   Amravati
# 29318           18  20251229  Maharashtra  Chhatrapati Sambhajinagar
#
# [29319 rows x 9 columns]

# %%
flagged_pincode_dominant=df_flagged.groupby(['district_clean', 'pincode'])[['bio_age_5_17','bio_age_17_']].sum().reset_index()
# flagged_pincode_dominant.to_excel('flagged_pincode_dominan.xlsx')

# %%
flagged_pincode_dominant['total_enroll']=flagged_pincode_dominant['bio_age_5_17']+flagged_pincode_dominant['bio_age_17_']
flagged_pincode_dominant.sort_values('pincode')
# Out:
#                 district_clean  pincode  bio_age_5_17  bio_age_17_  \
# 111                     Mumbai   400001           485          814
# 332                     Raigad   400001             6            9
# 0                   Ahmednagar   400003             5            3
# 112                     Mumbai   400003          1254         1747
# 32   Chhatrapati Sambhajinagar   400009             5            2
# ..                         ...      ...           ...          ...
# 16                       Akola   444502          1053         2929
# 17                       Akola   444503           140          479
# 410                     Washim   444503          5609        11857
# 18                       Akola   444802             5           10
# 20                    Amravati   444802          1290         2340
#
#      total_enroll
# 111          1299
# 332            15
# 0               8
# 112          3001
# 32              7
# ..            ...
# 16           3982
# 17            619
# 410         17466
# 18             15
# 20           3630
#
# [411 rows x 5 columns]

# %%
idx = flagged_pincode_dominant.groupby('pincode')['total_enroll'].idxmax()
df_filtered = flagged_pincode_dominant.loc[idx]
df_filtered
# Out:
#     district_clean  pincode  bio_age_5_17  bio_age_17_  total_enroll
# 111         Mumbai   400001           485          814          1299
# 112         Mumbai   400003          1254         1747          3001
# 113         Mumbai   400009          1688         2188          3876
# 114         Mumbai   400012          2702         3565          6267
# 115         Mumbai   400024           664         1495          2159
# ..             ...      ...           ...          ...           ...
# 14           Akola   444407           769         2733          3502
# 15           Akola   444501          3431         9099         12530
# 16           Akola   444502          1053         2929          3982
# 410         Washim   444503          5609        11857         17466
# 20        Amravati   444802          1290         2340          3630
#
# [193 rows x 5 columns]

# %%
df_maharashtra['pin_multi_district_flag'] = (
    df_maharashtra.groupby('pincode')['district']
      .transform('nunique') > 1
)

# %%
pin_district_map = (
    df_maharashtra[df_maharashtra['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']
    .unique()
    .reset_index()
)

# %%
file_path='pin_district_map.xlsx'
pin_district_map.to_excel(file_path, index=False)

# %%
df_maharashtra['pin_multi_district_flag'].value_counts()
# Out:
# pin_multi_district_flag
# False    87609
# True     63495
# Name: count, dtype: int64

# %%
df_maharashtra['total_enroll']=df_maharashtra['bio_age_5_17']+df_maharashtra['bio_age_17_']
df_maharashtra
# Out:
#                date        state    district  pincode  bio_age_5_17  \
# 5        01-03-2025  Maharashtra   Ratnagiri   416702           155
# 27       01-03-2025  Maharashtra      Wardha   442101           269
# 106      01-03-2025  Maharashtra    Amravati   444801           291
# 117      01-03-2025  Maharashtra       Dhule   424308           103
# 120      01-03-2025  Maharashtra   Ratnagiri   415606            47
# ...             ...          ...         ...      ...           ...
# 1860382  29-12-2025  Maharashtra    Amravati   444905             6
# 1860383  29-12-2025  Maharashtra  Aurangabad   431001           101
# 1860384  29-12-2025  Maharashtra  Aurangabad   431005             2
# 1860385  29-12-2025  Maharashtra  Aurangabad   431105            11
# 1860386  29-12-2025  Maharashtra  Aurangabad   431107             5
#
#          bio_age_17_  new_date  state_clean             district_clean  \
# 5                529  20250301  Maharashtra                  Ratnagiri
# 27               538  20250301  Maharashtra                     Wardha
# 106             1013  20250301  Maharashtra                   Amravati
# 117              355  20250301  Maharashtra                      Dhule
# 120              182  20250301  Maharashtra                  Ratnagiri
# ...              ...       ...          ...                        ...
# 1860382            7  20251229  Maharashtra                   Amravati
# 1860383          198  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860384           14  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860385           18  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860386           10  20251229  Maharashtra  Chhatrapati Sambhajinagar
#
#          pin_multi_district_flag  total_enroll
# 5                          False           684
# 27                         False           807
# 106                        False          1304
# 117                        False           458
# 120                        False           229
# ...                          ...           ...
# 1860382                    False            13
# 1860383                     True           299
# 1860384                     True            16
# 1860385                     True            29
# 1860386                     True            15
#
# [151104 rows x 11 columns]

# %%
df_maharashtra['month']=df_maharashtra['new_date'].astype(str).str[4:6]
df_maharashtra
# Out:
#                date        state    district  pincode  bio_age_5_17  \
# 5        01-03-2025  Maharashtra   Ratnagiri   416702           155
# 27       01-03-2025  Maharashtra      Wardha   442101           269
# 106      01-03-2025  Maharashtra    Amravati   444801           291
# 117      01-03-2025  Maharashtra       Dhule   424308           103
# 120      01-03-2025  Maharashtra   Ratnagiri   415606            47
# ...             ...          ...         ...      ...           ...
# 1860382  29-12-2025  Maharashtra    Amravati   444905             6
# 1860383  29-12-2025  Maharashtra  Aurangabad   431001           101
# 1860384  29-12-2025  Maharashtra  Aurangabad   431005             2
# 1860385  29-12-2025  Maharashtra  Aurangabad   431105            11
# 1860386  29-12-2025  Maharashtra  Aurangabad   431107             5
#
#          bio_age_17_  new_date  state_clean             district_clean  \
# 5                529  20250301  Maharashtra                  Ratnagiri
# 27               538  20250301  Maharashtra                     Wardha
# 106             1013  20250301  Maharashtra                   Amravati
# 117              355  20250301  Maharashtra                      Dhule
# 120              182  20250301  Maharashtra                  Ratnagiri
# ...              ...       ...          ...                        ...
# 1860382            7  20251229  Maharashtra                   Amravati
# 1860383          198  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860384           14  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860385           18  20251229  Maharashtra  Chhatrapati Sambhajinagar
# 1860386           10  20251229  Maharashtra  Chhatrapati Sambhajinagar
#
#          pin_multi_district_flag  total_enroll month
# 5                          False           684    03
# 27                         False           807    03
# 106                        False          1304    03
# 117                        False           458    03
# 120                        False           229    03
# ...                          ...           ...   ...
# 1860382                    False            13    12
# 1860383                     True           299    12
# 1860384                     True            16    12
# 1860385                     True            29    12
# 1860386                     True            15    12
#
# [151104 rows x 12 columns]

# %%
df_maharashtra_cleaned=df_maharashtra.drop(columns=['date','district','state'], axis=1)
df_maharashtra_cleaned
# Out:
#          pincode  bio_age_5_17  bio_age_17_  new_date  state_clean  \
# 5         416702           155          529  20250301  Maharashtra
# 27        442101           269          538  20250301  Maharashtra
# 106       444801           291         1013  20250301  Maharashtra
# 117       424308           103          355  20250301  Maharashtra
# 120       415606            47          182  20250301  Maharashtra
# ...          ...           ...          ...       ...          ...
# 1860382   444905             6            7  20251229  Maharashtra
# 1860383   431001           101          198  20251229  Maharashtra
# 1860384   431005             2           14  20251229  Maharashtra
# 1860385   431105            11           18  20251229  Maharashtra
# 1860386   431107             5           10  20251229  Maharashtra
#
#                     district_clean  pin_multi_district_flag  total_enroll  \
# 5                        Ratnagiri                    False           684
# 27                          Wardha                    False           807
# 106                       Amravati                    False          1304
# 117                          Dhule                    False           458
# 120                      Ratnagiri                    False           229
# ...                            ...                      ...           ...
# 1860382                   Amravati                    False            13
# 1860383  Chhatrapati Sambhajinagar                     True           299
# 1860384  Chhatrapati Sambhajinagar                     True            16
# 1860385  Chhatrapati Sambhajinagar                     True            29
# 1860386  Chhatrapati Sambhajinagar                     True            15
#
#         month
# 5          03
# 27         03
# 106        03
# 117        03
# 120        03
# ...       ...
# 1860382    12
# 1860383    12
# 1860384    12
# 1860385    12
# 1860386    12
#
# [151104 rows x 9 columns]

# %%
df_maharashtra_dist_level=df_maharashtra_cleaned.groupby('district_clean')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_maharashtra_dist_level.shape
# Out:
# (36, 3)

# %%
df_maharashtra_dist_level
# Out:
#                            bio_age_5_17  bio_age_17_  total_enroll
# district_clean
# Ahmednagar                       165848       203569        369417
# Akola                             53986       131099        185085
# Amravati                         103569       234714        338283
# Beed                             114597       150790        265387
# Bhandara                          31856        70348        102204
# Buldhana                          87702       167536        255238
# Chandrapur                        65688       147946        213634
# Chhatrapati Sambhajinagar        111578       206866        318444
# Dharashiv                         62809        92889        155698
# Dhule                             72244       125610        197854
# Gadchiroli                        38590       102075        140665
# Gondia                            35541        63246         98787
# Hingoli                           45691        71382        117073
# Jalgaon                          148853       268531        417384
# Jalna                             71820       120872        192692
# Kolhapur                         118410       152674        271084
# Latur                             74375       172366        246741
# Mumbai                           147992       303938        451930
# Mumbai Suburban                   99827        79290        179117
# Nagpur                           112851       238072        350923
# Nanded                           124730       217810        342540
# Nandurbar                         67162       134230        201392
# Nashik                           213100       363506        576606
# Palghar                           91196        66756        157952
# Parbhani                          77890       106136        184026
# Pune                             283480       322282        605762
# Raigad                            78629        92559        171188
# Ratnagiri                         56842        82347        139189
# Sangli                            94241       128772        223013
# Satara                           103754       105815        209569
# Sindhudurg                        21284        27093         48377
# Solapur                          154623       179884        334507
# Thane                            202896       368377        571273
# Wardha                            41487        84972        126459
# Washim                            44971        94488        139459
# Yavatmal                          92600       234587        327187

# %%
df_maharashtra_dist_level.sort_values('total_enroll', ascending=False).reset_index()
# df_maharashtra_dist_level.to_excel("df_maharashtra_dist_level.xlsx")
# Out:
#                district_clean  bio_age_5_17  bio_age_17_  total_enroll
# 0                        Pune        283480       322282        605762
# 1                      Nashik        213100       363506        576606
# 2                       Thane        202896       368377        571273
# 3                      Mumbai        147992       303938        451930
# 4                     Jalgaon        148853       268531        417384
# 5                  Ahmednagar        165848       203569        369417
# 6                      Nagpur        112851       238072        350923
# 7                      Nanded        124730       217810        342540
# 8                    Amravati        103569       234714        338283
# 9                     Solapur        154623       179884        334507
# 10                   Yavatmal         92600       234587        327187
# 11  Chhatrapati Sambhajinagar        111578       206866        318444
# 12                   Kolhapur        118410       152674        271084
# 13                       Beed        114597       150790        265387
# 14                   Buldhana         87702       167536        255238
# 15                      Latur         74375       172366        246741
# 16                     Sangli         94241       128772        223013
# 17                 Chandrapur         65688       147946        213634
# 18                     Satara        103754       105815        209569
# 19                  Nandurbar         67162       134230        201392
# 20                      Dhule         72244       125610        197854
# 21                      Jalna         71820       120872        192692
# 22                      Akola         53986       131099        185085
# 23                   Parbhani         77890       106136        184026
# 24            Mumbai Suburban         99827        79290        179117
# 25                     Raigad         78629        92559        171188
# 26                    Palghar         91196        66756        157952
# 27                  Dharashiv         62809        92889        155698
# 28                 Gadchiroli         38590       102075        140665
# 29                     Washim         44971        94488        139459
# 30                  Ratnagiri         56842        82347        139189
# 31                     Wardha         41487        84972        126459
# 32                    Hingoli         45691        71382        117073
# 33                   Bhandara         31856        70348        102204
# 34                     Gondia         35541        63246         98787
# 35                 Sindhudurg         21284        27093         48377

# %%
df_maharashtra_dist_level1=df_maharashtra_dist_level.head(10)

# %%
df_maharashtra_dist_level1.to_excel("df_maharashtra_dist_level1.xlsx")

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(18, 8))   # width, height in inches
sns.lineplot(data=df_maharashtra_dist_level1[['bio_age_5_17','bio_age_17_']])
plt.show()

# %%
df_maharashtra_pincode_level=df_maharashtra_cleaned.groupby('pincode')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
df_maharashtra_pincode_level.shape
# Out:
# (1607, 3)

# %%
df_maharashtra_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
# df_maharashtra_dist_level.to_excel("df_maharashtra_dist_level.xlsx")
# Out:
#       pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0      431001         27835        54661         82496
# 1      423203         28502        29968         58470
# 2      421302         17948        32031         49979
# 3      431122         21313        23629         44942
# 4      400043         15060        25004         40064
# ...       ...           ...          ...           ...
# 1602   400085             0            1             1
# 1603   425318             0            1             1
# 1604   402208             1            0             1
# 1605   400613             0            1             1
# 1606   400038             1            0             1
#
# [1607 rows x 4 columns]

# %%
df_maharashtra_pincode_level.sort_values('total_enroll', ascending=False).reset_index().head(20)
# Out:
#     pincode  bio_age_5_17  bio_age_17_  total_enroll
# 0    431001         27835        54661         82496
# 1    423203         28502        29968         58470
# 2    421302         17948        32031         49979
# 3    431122         21313        23629         44942
# 4    400043         15060        25004         40064
# 5    421301         15981        22399         38380
# 6    400612         13807        22223         36030
# 7    431203         12756        21773         34529
# 8    413512         12138        20203         32341
# 9    444001         11375        20201         31576
# 10   425001         13225        16093         29318
# 11   431401         12308        16476         28784
# 12   442001         10848        17794         28642
# 13   422003         10671        17910         28581
# 14   425412         10281        17853         28134
# 15   445204          8230        19895         28125
# 16   425414         10237        17781         28018
# 17   410206         13260        14452         27712
# 18   431712         10386        15502         25888
# 19   416416         12288        13146         25434

# %%
df_maharashtra_pincode_level.sort_values('total_enroll', ascending=False).reset_index().tail(20)
# Out:
#       pincode  bio_age_5_17  bio_age_17_  total_enroll
# 1587   416011             2            5             7
# 1588   400039             0            6             6
# 1589   425121             0            5             5
# 1590   442003             1            4             5
# 1591   416550             4            0             4
# 1592   413580             1            2             3
# 1593   445003             2            1             3
# 1594   425327             1            2             3
# 1595   425434             0            3             3
# 1596   400023             0            2             2
# 1597   416319             0            2             2
# 1598   431144             0            2             2
# 1599   425106             1            0             1
# 1600   416321             0            1             1
# 1601   416144             1            0             1
# 1602   400085             0            1             1
# 1603   425318             0            1             1
# 1604   402208             1            0             1
# 1605   400613             0            1             1
# 1606   400038             1            0             1

# %%
df_maharashtra_pincode_level.head(20)
# Out:
#          bio_age_5_17  bio_age_17_  total_enroll
# pincode
# 400001            491          823          1314
# 400002           1034         1657          2691
# 400003           1259         1750          3009
# 400004           1737         2349          4086
# 400005           1711         2587          4298
# 400006            603          884          1487
# 400007            659          902          1561
# 400008           3428         5313          8741
# 400009           1693         2190          3883
# 400010           2045         2435          4480
# 400011           2295         4086          6381
# 400012           2707         3574          6281
# 400013           1848         2518          4366
# 400014           1062         1262          2324
# 400015           1845         2906          4751
# 400016           2519         3215          5734
# 400017           6657        10533         17190
# 400018           2530         3139          5669
# 400019           1451         2130          3581
# 400020             62           50           112

# %%
df_maharashtra_pincode_level1=df_maharashtra_pincode_level.head(10)
df_maharashtra_pincode_level1
# Out:
#          bio_age_5_17  bio_age_17_  total_enroll
# pincode
# 400001            491          823          1314
# 400002           1034         1657          2691
# 400003           1259         1750          3009
# 400004           1737         2349          4086
# 400005           1711         2587          4298
# 400006            603          884          1487
# 400007            659          902          1561
# 400008           3428         5313          8741
# 400009           1693         2190          3883
# 400010           2045         2435          4480

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))   # width, height in inches
sns.lineplot(data=df_maharashtra_pincode_level1[['bio_age_5_17','bio_age_17_']])
plt.show()

# %%
maharashtra_month_enroll_trend=df_maharashtra_cleaned.groupby('month')[['bio_age_5_17','bio_age_17_','total_enroll']].sum()
maharashtra_month_enroll_trend
# Out:
#        bio_age_5_17  bio_age_17_  total_enroll
# month
# 03           300370       658779        959149
# 04           282523       563526        846049
# 05           300215       647561        947776
# 06           339273       678217       1017490
# 07           453411       776958       1230369
# 09           698647       425802       1124449
# 10           225372       516260        741632
# 11           397550       819649       1217199
# 12           515351       626675       1142026

# %%
maharashtra_month_enroll_trend.to_excel("df_maharashtra_month_level.xlsx")

# %%
sns.lineplot(data=maharashtra_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# # EDA on Demographic data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing demographic file 1

# %%
demo_1=pd.read_csv('api_data_aadhar_demographic_0_500000.csv')
demo_1.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
demo_1.shape
# Out:
# (500000, 6)

# %%
demo_1['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu and Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur', 'Daman and Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Dadra and Nagar Haveli', 'Orissa', 'Pondicherry',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'west Bengal', 'Daman & Diu', 'West  Bengal', 'odisha',
#        'Jammu & Kashmir', 'Lakshadweep', 'Dadra & Nagar Haveli',
#        'Westbengal', 'andhra pradesh', 'WEST BENGAL', 'West Bangal',
#        'West bengal', 'ODISHA', 'WESTBENGAL', 'Chhatisgarh',
# ...

# %%
demo_1['state'].nunique()
# Out:
# 58

# %%
demo_1['new_date'] = pd.to_datetime(
    demo_1['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_1
# Out:
#               date           state    district  pincode  demo_age_5_17  \
# 0       01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1       01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2       01-03-2025         Gujarat      Rajkot   360006             65
# 3       01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4       01-03-2025       Rajasthan     Udaipur   313801             45
# ...            ...             ...         ...      ...            ...
# 499995  19-09-2025     Maharashtra      Satara   415212              0
# 499996  19-09-2025     Maharashtra      Satara   415312              0
# 499997  19-09-2025     Maharashtra      Satara   415510              0
# 499998  19-09-2025     Maharashtra      Satara   415511              0
# 499999  19-09-2025     Maharashtra      Satara   415516              0
#
#         demo_age_17_  new_date
# 0                529  20250301
# 1                375  20250301
# ...

# %%
demo_1['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_1['new_date'].max())
print(demo_1['new_date'].min())
# Out:
# 20251229
# 20250301

# %% [markdown]
# ##  Importing demographic file 2

# %%
demo_2=pd.read_csv('api_data_aadhar_demographic_500000_1000000.csv')
demo_2.head()
# Out:
#          date        state    district  pincode  demo_age_5_17  demo_age_17_
# 0  19-09-2025  Maharashtra      Satara   415517              0             2
# 1  19-09-2025  Maharashtra      Satara   415518              0             2
# 2  19-09-2025  Maharashtra      Satara   415520              0             3
# 3  19-09-2025  Maharashtra      Satara   415539              1             5
# 4  19-09-2025  Maharashtra  Sindhudurg   416510              4            37

# %%
demo_2.shape
# Out:
# (500000, 6)

# %%
demo_2['state'].unique()
# Out:
# array(['Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'ODISHA', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Sikkim', 'Uttarakhand', 'West  Bengal',
#        'West Bengal', 'Andaman & Nicobar Islands', 'odisha',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Lakshadweep', 'Madhya Pradesh', 'Ladakh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'west Bengal', 'Daman & Diu', 'Dadra & Nagar Haveli',
#        'West Bangal', 'Westbengal', 'andhra pradesh', 'WESTBENGAL',
#        'WEST BENGAL', 'West bengal', 'West Bengli', 'BALANAGAR',
# ...

# %%
demo_2['state'].nunique()
# Out:
# 61

# %%
demo_2['new_date'] = pd.to_datetime(
    demo_2['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_2
# Out:
#               date          state    district  pincode  demo_age_5_17  \
# 0       19-09-2025    Maharashtra      Satara   415517              0
# 1       19-09-2025    Maharashtra      Satara   415518              0
# 2       19-09-2025    Maharashtra      Satara   415520              0
# 3       19-09-2025    Maharashtra      Satara   415539              1
# 4       19-09-2025    Maharashtra  Sindhudurg   416510              4
# ...            ...            ...         ...      ...            ...
# 499995  31-10-2025  Uttar Pradesh        Etah   207250              2
# 499996  31-10-2025  Uttar Pradesh        Etah   207401              1
# 499997  31-10-2025  Uttar Pradesh      Etawah   206003              3
# 499998  31-10-2025  Uttar Pradesh      Etawah   206125              1
# 499999  31-10-2025  Uttar Pradesh      Etawah   206126              1
#
#         demo_age_17_  new_date
# 0                  2  20250919
# 1                  2  20250919
# ...

# %%
demo_2['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_2['new_date'].max())
print(demo_2['new_date'].min())
# Out:
# 20251229
# 20250301

# %% [markdown]
# ##  Importing demographic file 3

# %%
demo_3=pd.read_csv('api_data_aadhar_demographic_1000000_1500000.csv')
demo_3.head()
# Out:
#          date       state    district  pincode  demo_age_5_17  demo_age_17_
# 0  01-11-2025  Puducherry    Karaikal   609603              0             4
# 1  01-11-2025  Puducherry    Karaikal   609605              0             3
# 2  01-11-2025  Puducherry    Karaikal   609606              0             5
# 3  01-11-2025  Puducherry  Puducherry   605011              2             6
# 4  01-11-2025  Puducherry  Puducherry   605111              0             1

# %%
demo_3.shape
# Out:
# (500000, 6)

# %%
demo_3['state'].unique()
# Out:
# array(['Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh',
#        'Chhattisgarh', 'Dadra & Nagar Haveli', 'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh',
#        'andhra pradesh', 'Daman & Diu', 'Lakshadweep', 'West Bangal',
#        'Jammu & Kashmir', 'Andaman & Nicobar Islands', 'ODISHA',
#        'WESTBENGAL', 'West  Bengal', 'West bengal', 'Westbengal',
#        'odisha', 'WEST BENGAL', 'Uttaranchal', 'west Bengal',
# ...

# %%
demo_3['state'].nunique()
# Out:
# 56

# %%
demo_3['new_date'] = pd.to_datetime(
    demo_3['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_3
# Out:
#               date       state    district  pincode  demo_age_5_17  \
# 0       01-11-2025  Puducherry    Karaikal   609603              0
# 1       01-11-2025  Puducherry    Karaikal   609605              0
# 2       01-11-2025  Puducherry    Karaikal   609606              0
# 3       01-11-2025  Puducherry  Puducherry   605011              2
# 4       01-11-2025  Puducherry  Puducherry   605111              0
# ...            ...         ...         ...      ...            ...
# 499995  19-11-2025   Rajasthan       Baran   325217              5
# 499996  19-11-2025   Rajasthan       Baran   325219              2
# 499997  19-11-2025   Rajasthan       Baran   325221             12
# 499998  19-11-2025   Rajasthan      Barmer   344011              1
# 499999  19-11-2025   Rajasthan      Barmer   344022              6
#
#         demo_age_17_  new_date
# 0                  4  20251101
# 1                  3  20251101
# 2                  5  20251101
# 3                  6  20251101
# ...

# %%
demo_3['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_3['new_date'].max())
print(demo_3['new_date'].min())
# Out:
# 20251229
# 20250301

# %% [markdown]
# ##  Importing demographic file 4

# %%
demo_4=pd.read_csv('api_data_aadhar_demographic_1500000_2000000.csv')
demo_4.head()
# Out:
#          date      state district  pincode  demo_age_5_17  demo_age_17_
# 0  18-11-2025  Karnataka    Hasan   573118              0             2
# 1  18-11-2025  Karnataka    Hasan   573124              1             3
# 2  18-11-2025  Karnataka    Hasan   573150              0             2
# 3  18-11-2025  Karnataka   Hassan   573113              0             1
# 4  18-11-2025  Karnataka   Hassan   573120              1             4

# %%
demo_4.shape
# Out:
# (500000, 6)

# %%
demo_4['state'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Jammu and Kashmir', 'Jharkhand',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
#        'Andaman and Nicobar Islands', 'Andhra Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman & Diu',
#        'Daman and Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'ODISHA',
#        'Arunachal Pradesh', 'Tripura', 'Andaman & Nicobar Islands',
#        'Lakshadweep', 'West Bengli', 'West  Bengal', 'West Bangal',
#        'Westbengal', 'Dadra & Nagar Haveli', 'West bengal', 'BALANAGAR',
#        'Uttaranchal', 'WESTBENGAL', 'WEST BENGAL', 'Jaipur',
# ...

# %%
demo_4['state'].nunique()
# Out:
# 59

# %%
demo_4['new_date'] = pd.to_datetime(
    demo_4['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_4
# Out:
#               date        state   district  pincode  demo_age_5_17  \
# 0       18-11-2025    Karnataka      Hasan   573118              0
# 1       18-11-2025    Karnataka      Hasan   573124              1
# 2       18-11-2025    Karnataka      Hasan   573150              0
# 3       18-11-2025    Karnataka     Hassan   573113              0
# 4       18-11-2025    Karnataka     Hassan   573120              1
# ...            ...          ...        ...      ...            ...
# 499995  16-12-2025  Maharashtra  Dharashiv   413506              1
# 499996  16-12-2025  Maharashtra  Dharashiv   413507              0
# 499997  16-12-2025  Maharashtra  Dharashiv   413601              0
# 499998  16-12-2025  Maharashtra  Dharashiv   413602              0
# 499999  16-12-2025  Maharashtra      Dhule   424301              0
#
#         demo_age_17_  new_date
# 0                  2  20251118
# 1                  3  20251118
# 2                  2  20251118
# 3                  1  20251118
# ...

# %%
demo_4['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_4['new_date'].max())
print(demo_4['new_date'].min())
# Out:
# 20251229
# 20250301

# %% [markdown]
# ##  Importing demographic file 5

# %%
demo_5=pd.read_csv('api_data_aadhar_demographic_2000000_2071700.csv')
demo_5.head()
# Out:
#          date           state  district  pincode  demo_age_5_17  demo_age_17_
# 0  16-12-2025  Madhya Pradesh  Shajapur   465113              0             4
# 1  16-12-2025  Madhya Pradesh  Shajapur   465226              2            14
# 2  16-12-2025  Madhya Pradesh  Shajapur   465339              1             2
# 3  16-12-2025  Madhya Pradesh  Shajapur   465447              1            19
# 4  16-12-2025  Madhya Pradesh   Sheopur   476332             11            25

# %%
demo_5.shape
# Out:
# (71700, 6)

# %%
demo_5['state'].unique()
# Out:
# array(['Madhya Pradesh', 'Maharashtra', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bangal', 'West Bengal', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Orissa', 'Pondicherry', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'West bengal', 'andhra pradesh', 'west Bengal',
#        'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Daman & Diu',
#        'Daman and Diu', 'Ladakh', 'Lakshadweep', 'Sikkim', 'Westbengal',
#        '100000', 'Andaman & Nicobar Islands',
#        'Andaman and Nicobar Islands', 'Dadra & Nagar Haveli', 'ODISHA',
#        'odisha', 'Nagpur', 'WESTBENGAL', 'WEST BENGAL',
# ...

# %%
demo_5['state'].nunique()
# Out:
# 57

# %%
demo_5['new_date'] = pd.to_datetime(
    demo_5['date'],
    dayfirst=True,
    errors='coerce'
).dt.strftime('%Y%m%d')
demo_5
# Out:
#              date           state        district  pincode  demo_age_5_17  \
# 0      16-12-2025  Madhya Pradesh        Shajapur   465113              0
# 1      16-12-2025  Madhya Pradesh        Shajapur   465226              2
# 2      16-12-2025  Madhya Pradesh        Shajapur   465339              1
# 3      16-12-2025  Madhya Pradesh        Shajapur   465447              1
# 4      16-12-2025  Madhya Pradesh         Sheopur   476332             11
# ...           ...             ...             ...      ...            ...
# 71695  29-12-2025     West Bengal  West Midnapore   721212              0
# 71696  29-12-2025     West Bengal  West Midnapore   721420              0
# 71697  29-12-2025     West Bengal  West Midnapore   721424              0
# 71698  29-12-2025     West Bengal  West Midnapore   721426              0
# 71699  29-12-2025     West Bengal         hooghly   712701              0
#
#        demo_age_17_  new_date
# 0                 4  20251216
# ...

# %%
demo_5['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
print(demo_5['new_date'].max())
print(demo_5['new_date'].min())
# Out:
# 20251229
# 20251125

# %% [markdown]
# ###  Merging five datasets

# %%
df = pd.concat([demo_1, demo_2, demo_3, demo_4, demo_5], axis=0, ignore_index=True)
df.shape
# Out:
# (2071700, 7)

# %%
df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_  new_date
# 0           529  20250301
# 1           375  20250301
# 2           765  20250301
# 3           314  20250301
# 4           785  20250301

# %%
df['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['state'].nunique()
# Out:
# 65

# %%
df['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu and Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur', 'Daman and Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Dadra and Nagar Haveli', 'Orissa', 'Pondicherry',
#        'Andaman & Nicobar Islands', 'Andaman and Nicobar Islands',
#        'west Bengal', 'Daman & Diu', 'West  Bengal', 'odisha',
#        'Jammu & Kashmir', 'Lakshadweep', 'Dadra & Nagar Haveli',
#        'Westbengal', 'andhra pradesh', 'WEST BENGAL', 'West Bangal',
#        'West bengal', 'ODISHA', 'WESTBENGAL', 'Chhatisgarh',
# ...

# %%
df[df['state']=='Darbhanga']
# Out:
#               date      state               district  pincode  demo_age_5_17  \
# 222931  16-12-2025  Darbhanga  Near University Thana   846004              0
# 332384  16-12-2025  Darbhanga  Near University Thana   846004              0
#
#         demo_age_17_  new_date
# 222931             1  20251216
# 332384             1  20251216

# %%
df[df['state']=='Puttenahalli']
# Out:
#               date         state   district  pincode  demo_age_5_17  \
# 341349  19-12-2025  Puttenahalli  5th cross   560078              0
#
#         demo_age_17_  new_date
# 341349             1  20251219

# %%
df[df['state']=='BALANAGAR']
# Out:
#                date      state     district  pincode  demo_age_5_17  \
# 731443   13-12-2025  BALANAGAR  IDPL COLONY   500037              0
# 1557006  13-12-2025  BALANAGAR  IDPL COLONY   500037              0
#
#          demo_age_17_  new_date
# 731443              1  20251213
# 1557006             1  20251213

# %%
df[df['state']=='Uttaranchal']
# Out:
#                date        state             district  pincode  demo_age_5_17  \
# 759992   20-12-2025  Uttaranchal  Udham Singh Nagar *   244712              0
# 1205510  22-12-2025  Uttaranchal        Tehri Garhwal   249132              0
# 1566917  19-12-2025  Uttaranchal  Udham Singh Nagar *   244712              0
# 1598662  20-12-2025  Uttaranchal  Udham Singh Nagar *   244712              0
# 1623945  22-12-2025  Uttaranchal        Tehri Garhwal   249132              0
#
#          demo_age_17_  new_date
# 759992              1  20251220
# 1205510             1  20251222
# 1566917             1  20251219
# 1598662             1  20251220
# 1623945             1  20251222

# %%
df[df['state']=='Jaipur']
# Out:
#                date   state             district  pincode  demo_age_5_17  \
# 812275   26-12-2025  Jaipur  Near meera hospital   302016              0
# 1610763  26-12-2025  Jaipur  Near meera hospital   302016              0
#
#          demo_age_17_  new_date
# 812275              1  20251226
# 1610763             1  20251226

# %%
df[df['state']=='Madanapalle']
# Out:
#                date        state     district  pincode  demo_age_5_17  \
# 815006   27-12-2025  Madanapalle  Kadiri Road   517325              0
# 1631579  27-12-2025  Madanapalle  Kadiri Road   517325              0
#
#          demo_age_17_  new_date
# 815006              1  20251227
# 1631579             1  20251227

# %%
df[df['state']=='Raja Annamalai Puram']
# Out:
#                date                 state            district  pincode  \
# 2057984  26-12-2025  Raja Annamalai Puram  Near Dhyana Ashram   600028
#
#          demo_age_5_17  demo_age_17_  new_date
# 2057984              0             1  20251226

# %%
df[df['state']=='Nagpur']
# Out:
#                date   state                    district  pincode  \
# 2033255  22-12-2025  Nagpur  Near Uday nagar NIT garden   440024
#
#          demo_age_5_17  demo_age_17_  new_date
# 2033255              0             1  20251222

# %%
df[df['state']=='100000']
# Out:
#                date   state district  pincode  demo_age_5_17  demo_age_17_  \
# 795161   23-12-2025  100000   100000   100000              0             1
# 2007370  20-12-2025  100000   100000   100000              0             1
#
#          new_date
# 795161   20251223
# 2007370  20251220

# %%
df.drop(df[df['state'] =='100000'].index, inplace=True)

# %%
df['state'] = df['state'].replace('Darbhanga', 'Bihar')

# %%
df['state'] = df['state'].replace('Puttenahalli', 'Karnataka')

# %%
df['state'] = df['state'].replace('BALANAGAR', 'Telangana')

# %%
df['state'] = df['state'].replace('Uttaranchal', 'Uttarakhand')

# %%
df['state'] = df['state'].replace('Jaipur', 'Rajasthan')

# %%
df['state'] = df['state'].replace('Raja Annamalai Puram','Tamil Nadu')

# %%
df['state'] = df['state'].replace('Nagpur', 'Maharashtra')

# %%
df['state'] = df['state'].replace('Madanapalle', 'Andhra Pradesh')

# %%
import pandas as pd
import re

def clean_state_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove symbols like &, .
    x = re.sub(r'\s+', ' ', x).strip()  # remove extra spaces
    return x

# %%
state_mapping = {

    # Andhra Pradesh
    'andhra pradesh': 'Andhra Pradesh',

    # Arunachal Pradesh
    'arunachal pradesh': 'Arunachal Pradesh',

    # Assam
    'assam': 'Assam',

    # Bihar
    'bihar': 'Bihar',

    # Chandigarh
    'chandigarh': 'Chandigarh',

    # Chhattisgarh
    'chhattisgarh': 'Chhattisgarh',
    'chhatisgarh': 'Chhattisgarh',

    # Dadra & Nagar Haveli and Daman & Diu (merged UT)
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli and daman and diu':'Dadra and Nagar Haveli and Daman and Diu',
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',
    

    # Andaman & Nicobar Islands
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Delhi
    'delhi': 'Delhi',

    # Goa
    'goa': 'Goa',

    # Gujarat
    'gujarat': 'Gujarat',

    # Haryana
    'haryana': 'Haryana',

    # Himachal Pradesh
    'himachal pradesh': 'Himachal Pradesh',

    # Jammu & Kashmir
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',

    # Jharkhand
    'jharkhand': 'Jharkhand',

    # Karnataka
    'karnataka': 'Karnataka',

    # Kerala
    'kerala': 'Kerala',

    # Ladakh
    'ladakh': 'Ladakh',

    # Lakshadweep
    'lakshadweep': 'Lakshadweep',

    # Madhya Pradesh
    'madhya pradesh': 'Madhya Pradesh',

    # Maharashtra
    'maharashtra': 'Maharashtra',

    # Manipur
    'manipur': 'Manipur',

    # Meghalaya
    'meghalaya': 'Meghalaya',

    # Mizoram
    'mizoram': 'Mizoram',

    # Nagaland
    'nagaland': 'Nagaland',

    # Odisha
    'odisha': 'Odisha',
    'orissa': 'Odisha',

    # Puducherry
    'puducherry': 'Puducherry',
    'pondicherry': 'Puducherry',

    # Punjab
    'punjab': 'Punjab',

    # Rajasthan
    'rajasthan': 'Rajasthan',

    # Sikkim
    'sikkim': 'Sikkim',

    # Tamil Nadu
    'tamil nadu': 'Tamil Nadu',

    # Telangana
    'telangana': 'Telangana',

    # Tripura
    'tripura': 'Tripura',

    # Uttar Pradesh
    'uttar pradesh': 'Uttar Pradesh',

    # Uttarakhand
    'uttarakhand': 'Uttarakhand',
    'uttaranchal': 'Uttarakhand',

    # West Bengal
    'west bengal': 'West Bengal',
    'west  bengal': 'West Bengal',
    'westbengal': 'West Bengal',
    'west bangal': 'West Bengal',
    'west bengli': 'West Bengal'
}

# %%
df['state_clean'] = (
    df['state']
    .apply(clean_state_name)
    .map(state_mapping)
)

# %%
# Drop invalid entries like numeric junk
df = df[~df['state'].astype(str).str.isnumeric()]

# Optional: check unmapped states
unmapped = df[df['state_clean'].isna()]['state'].unique()
print("Unmapped values:", unmapped)
# Out:
# Unmapped values: []

# %%
df['state_clean'].unique()
# Out:
# array(['Uttar Pradesh', 'Andhra Pradesh', 'Gujarat', 'Rajasthan',
#        'Karnataka', 'West Bengal', 'Telangana', 'Odisha', 'Maharashtra',
#        'Kerala', 'Bihar', 'Tamil Nadu', 'Madhya Pradesh', 'Assam',
#        'Tripura', 'Arunachal Pradesh', 'Punjab', 'Jharkhand', 'Delhi',
#        'Chandigarh', 'Chhattisgarh', 'Jammu and Kashmir', 'Mizoram',
#        'Nagaland', 'Himachal Pradesh', 'Goa', 'Haryana', 'Meghalaya',
#        'Uttarakhand', 'Manipur',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Puducherry', 'Sikkim',
#        'Ladakh', 'Andaman and Nicobar Islands', 'Lakshadweep'],
#       dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
df
# Out:
#                date           state        district  pincode  demo_age_5_17  \
# 0        01-03-2025   Uttar Pradesh       Gorakhpur   273213             49
# 1        01-03-2025  Andhra Pradesh        Chittoor   517132             22
# 2        01-03-2025         Gujarat          Rajkot   360006             65
# 3        01-03-2025  Andhra Pradesh      Srikakulam   532484             24
# 4        01-03-2025       Rajasthan         Udaipur   313801             45
# ...             ...             ...             ...      ...            ...
# 2071695  29-12-2025     West Bengal  West Midnapore   721212              0
# 2071696  29-12-2025     West Bengal  West Midnapore   721420              0
# 2071697  29-12-2025     West Bengal  West Midnapore   721424              0
# 2071698  29-12-2025     West Bengal  West Midnapore   721426              0
# 2071699  29-12-2025     West Bengal         hooghly   712701              0
#
#          demo_age_17_  new_date     state_clean
# ...

# %%
df.dtypes
# Out:
# date             object
# state            object
# district         object
# pincode           int64
# demo_age_5_17     int64
# demo_age_17_      int64
# new_date         object
# state_clean      object
# dtype: object

# %%
df_maharashtra=df[df['state_clean']=='Maharashtra'].copy()
df_maharashtra
# Out:
#                date        state  district  pincode  demo_age_5_17  \
# 15       01-03-2025  Maharashtra    Nashik   422305             13
# 29       01-03-2025  Maharashtra   Jalgaon   425310             30
# 84       01-03-2025  Maharashtra    Nagpur   440007             10
# 110      01-03-2025  Maharashtra    Mumbai   400097             28
# 152      01-03-2025  Maharashtra   Solapur   413214             22
# ...             ...          ...       ...      ...            ...
# 2065029  28-12-2025  Maharashtra  Yavatmal   445206              2
# 2065030  28-12-2025  Maharashtra  Yavatmal   445211              0
# 2065031  28-12-2025  Maharashtra  Yavatmal   445215              0
# 2065032  28-12-2025  Maharashtra  Yavatmal   445216              0
# 2065033  28-12-2025  Maharashtra  Yavatmal   445304              1
#
#          demo_age_17_  new_date  state_clean
# 15                227  20250301  Maharashtra
# 29                685  20250301  Maharashtra
# ...

# %%
df_maharashtra['district'].unique()
# Out:
# array(['Nashik', 'Jalgaon', 'Nagpur', 'Mumbai', 'Solapur', 'Palghar',
#        'Amravati', 'Parbhani', 'Jalna', 'Ahmadnagar', 'Ratnagiri',
#        'Mumbai Suburban', 'Pune', 'Buldhana', 'Satara', 'Chandrapur',
#        'Aurangabad', 'Osmanabad', 'Yavatmal', 'Latur', 'Nandurbar',
#        'Kolhapur', 'Thane', 'Raigarh', 'Akola', 'Beed', 'Dhule', 'Nanded',
#        'Gadchiroli', 'Mumbai City', 'Raigad', 'Sindhudurg', 'Washim',
#        'Sangli', 'Gondiya', 'Chhatrapati Sambhajinagar', 'Wardha',
#        'Ahmed Nagar', 'Bhandara', 'Bid', 'Buldana', 'Dharashiv', 'Gondia',
#        'Gondiya *', 'Hingoli', 'Mumbai( Sub Urban )',
#        'Chatrapati Sambhaji Nagar', 'Nandurbar *', 'Raigarh(MH)',
#        'Washim *', 'Ahilyanagar', 'Dist : Thane', 'Hingoli *',
#        'Near Uday nagar NIT garden'], dtype=object)

# %%
import re
import pandas as pd

def clean_name(x):
    if pd.isna(x):
        return x
    x = str(x).lower()
    x = re.sub(r'[^a-z\s]', ' ', x)   # remove (), ., etc
    x = re.sub(r'\s+', ' ', x).strip()
    return x

# %%
df_maharashtra['district'] = df_maharashtra['district'].replace('Near Uday nagar NIT garden', 'Nagpur')

# %%
district_mapping_maharashtra = {

    # Ahmednagar (Ahilyanagar)
    'ahmadnagar': 'Ahmednagar',
    'ahmed nagar': 'Ahmednagar',
    'ahilyanagar': 'Ahmednagar',

    # Akola
    'akola': 'Akola',

    # Amravati
    'amravati': 'Amravati',

    # Aurangabad → Chhatrapati Sambhajinagar
    'aurangabad': 'Chhatrapati Sambhajinagar',
    'chhatrapati sambhajinagar': 'Chhatrapati Sambhajinagar',
    'chatrapati sambhaji nagar': 'Chhatrapati Sambhajinagar',

    # Beed
    'beed': 'Beed',
    'bid': 'Beed',

    # Bhandara
    'bhandara': 'Bhandara',

    # Buldhana
    'buldhana': 'Buldhana',
    'buldana': 'Buldhana',

    # Chandrapur
    'chandrapur': 'Chandrapur',

    # Dharashiv (Osmanabad)
    'osmanabad': 'Dharashiv',
    'dharashiv': 'Dharashiv',

    # Dhule
    'dhule': 'Dhule',

    # Gadchiroli
    'gadchiroli': 'Gadchiroli',

    # Gondia
    'gondia': 'Gondia',
    'gondiya': 'Gondia',
    'gondiya *': 'Gondia',

    # Hingoli
    'hingoli': 'Hingoli',
    'hingoli *': 'Hingoli',

    # Jalgaon
    'jalgaon': 'Jalgaon',

    # Jalna
    'jalna': 'Jalna',

    # Kolhapur
    'kolhapur': 'Kolhapur',

    # Latur
    'latur': 'Latur',

    # Mumbai
    'mumbai': 'Mumbai',
    'mumbai city': 'Mumbai',

    # Mumbai Suburban
    'mumbai suburban': 'Mumbai Suburban',
    'mumbai sub urban': 'Mumbai Suburban',
    'mumbai( sub urban )': 'Mumbai Suburban',

    # Nagpur
    'nagpur': 'Nagpur',

    # Nanded
    'nanded': 'Nanded',

    # Nandurbar
    'nandurbar': 'Nandurbar',
    'nandurbar *': 'Nandurbar',

    # Nashik
    'nashik': 'Nashik',

    # Palghar
    'palghar': 'Palghar',

    # Parbhani
    'parbhani': 'Parbhani',

    # Pune
    'pune': 'Pune',

    # Raigad
    'raigad': 'Raigad',
    'raigarh': 'Raigad',
    'raigarh mh': 'Raigad',

    # Ratnagiri
    'ratnagiri': 'Ratnagiri',

    # Sangli
    'sangli': 'Sangli',

    # Satara
    'satara': 'Satara',

    # Sindhudurg
    'sindhudurg': 'Sindhudurg',

    # Solapur
    'solapur': 'Solapur',

    # Thane
    'thane': 'Thane',
    'dist thane': 'Thane',

    # Wardha
    'wardha': 'Wardha',

    # Washim
    'washim': 'Washim',
    'washim *': 'Washim',

    # Yavatmal
    'yavatmal': 'Yavatmal'
}

# %%
df_maharashtra['district_clean'] = (
    df_maharashtra['district']
    .apply(clean_name)
    .map(district_mapping_maharashtra)
    .fillna(df_maharashtra['district'])
)

# %%
# Remaining unmappped
df_maharashtra[df_maharashtra['district_clean'].isna()]['district'].unique()

# count check
df_maharashtra['district_clean'].nunique()
# Out:
# 36

# %%
df_maharashtra
# Out:
#                date        state  district  pincode  demo_age_5_17  \
# 15       01-03-2025  Maharashtra    Nashik   422305             13
# 29       01-03-2025  Maharashtra   Jalgaon   425310             30
# 84       01-03-2025  Maharashtra    Nagpur   440007             10
# 110      01-03-2025  Maharashtra    Mumbai   400097             28
# 152      01-03-2025  Maharashtra   Solapur   413214             22
# ...             ...          ...       ...      ...            ...
# 2065029  28-12-2025  Maharashtra  Yavatmal   445206              2
# 2065030  28-12-2025  Maharashtra  Yavatmal   445211              0
# 2065031  28-12-2025  Maharashtra  Yavatmal   445215              0
# 2065032  28-12-2025  Maharashtra  Yavatmal   445216              0
# 2065033  28-12-2025  Maharashtra  Yavatmal   445304              1
#
#          demo_age_17_  new_date  state_clean district_clean
# 15                227  20250301  Maharashtra         Nashik
# ...

# %%
df_maharashtra['new_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_maharashtra['pincode'].nunique()
# Out:
# 1609

# %%
# df_maharashtra[['district_clean','pincode']].value_count().reset_index(name='count')

# %%
df_maharashtra[df_maharashtra['district_clean']== 'Thane']['pincode'].unique()
# Out:
# array([401101, 400608, 421302, 421301, 421308, 421501, 421002, 400706,
#        400607, 400615, 400604, 421403, 400612, 400603, 400605, 401104,
#        401204, 401209, 401305, 401404, 401601, 401604, 401605, 401702,
#        421003, 421102, 421201, 421312, 421506, 400601, 401302, 401503,
#        421004, 421005, 421204, 421311, 421402, 421605, 400606, 401106,
#        401301, 401405, 401502, 401602, 401606, 401610, 421502, 421604,
#        400705, 401201, 401203, 401303, 401401, 401504, 401506, 421401,
#        421505, 421602, 401103, 401202, 421203, 421503, 400610, 400709,
#        401603, 421001, 421303, 400703, 421306, 401107, 401206, 401304,
#        401402, 400710, 401208, 401607, 421101, 421601, 421305, 421103,
#        401207, 401403, 421603, 400614, 400708, 401105, 400701, 401501,
#        401102, 401703, 401701, 401609, 400602, 421202, 421304, 401608])

# %%
pin_district_count = (
    df_maharashtra.groupby('pincode')['district_clean']
    .nunique()
    .reset_index(name='district_count')
)

# %%
pin_district_count
# Out:
#       pincode  district_count
# 0      400001               2
# 1      400002               1
# 2      400003               2
# 3      400004               1
# 4      400005               1
# ...       ...             ...
# 1604   445307               1
# 1605   445308               1
# 1606   445323               1
# 1607   445401               1
# 1608   445402               1
#
# [1609 rows x 2 columns]

# %%
problem_pins = pin_district_count[
    pin_district_count['district_count'] > 1
]

# %%
problem_pins
# Out:
#       pincode  district_count
# 0      400001               2
# 2      400003               2
# 8      400009               2
# 11     400012               3
# 22     400024               2
# ...       ...             ...
# 1522   444407               2
# 1524   444501               2
# 1525   444502               2
# 1526   444503               2
# 1557   444802               2
#
# [195 rows x 2 columns]

# %%
df_flagged = df_maharashtra.merge(
    problem_pins[['pincode']],
    on='pincode',
    how='inner'
)

# %%
df_flagged
# Out:
#              date        state         district  pincode  demo_age_5_17  \
# 0      01-03-2025  Maharashtra           Mumbai   400097             28
# 1      01-03-2025  Maharashtra          Palghar   401501             48
# 2      01-03-2025  Maharashtra  Mumbai Suburban   400079             36
# 3      01-03-2025  Maharashtra  Mumbai Suburban   400029             21
# 4      01-03-2025  Maharashtra        Osmanabad   413501             77
# ...           ...          ...              ...      ...            ...
# 31947  28-12-2025  Maharashtra           Sangli   416403              0
# 31948  28-12-2025  Maharashtra            Thane   401305              0
# 31949  28-12-2025  Maharashtra            Thane   401603              0
# 31950  28-12-2025  Maharashtra            Thane   401605              0
# 31951  28-12-2025  Maharashtra           Wardha   442302              1
#
#        demo_age_17_  new_date  state_clean   district_clean
# ...

# %%
flagged_pincode_dominant=df_flagged.groupby(['district_clean', 'pincode'])[['demo_age_5_17','demo_age_17_']].sum().reset_index()
# flagged_pincode_dominant.to_excel('flagged_pincode_dominan.xlsx')

# %%
flagged_pincode_dominant['total_enroll']=flagged_pincode_dominant['demo_age_5_17']+flagged_pincode_dominant['demo_age_17_']
flagged_pincode_dominant.sort_values('pincode')
# Out:
#     district_clean  pincode  demo_age_5_17  demo_age_17_  total_enroll
# 118         Mumbai   400001             42           572           614
# 340         Raigad   400001              1            47            48
# 0       Ahmednagar   400003              0             5             5
# 119         Mumbai   400003            165          1951          2116
# 120         Mumbai   400009            166          1804          1970
# ..             ...      ...            ...           ...           ...
# 416         Washim   444502              0             1             1
# 417         Washim   444503            129          5826          5955
# 18           Akola   444503              5           127           132
# 21        Amravati   444802             95          1378          1473
# 19           Akola   444802              0            10            10
#
# [418 rows x 5 columns]

# %%
idx = flagged_pincode_dominant.groupby('pincode')['total_enroll'].idxmax()
df_filtered = flagged_pincode_dominant.loc[idx]
df_filtered
# Out:
#       district_clean  pincode  demo_age_5_17  demo_age_17_  total_enroll
# 118           Mumbai   400001             42           572           614
# 119           Mumbai   400003            165          1951          2116
# 120           Mumbai   400009            166          1804          1970
# 121           Mumbai   400012            231          3751          3982
# 220  Mumbai Suburban   400024             84           935          1019
# ..               ...      ...            ...           ...           ...
# 15             Akola   444407             68          1024          1092
# 16             Akola   444501            119          3930          4049
# 17             Akola   444502             58           650           708
# 417           Washim   444503            129          5826          5955
# 21          Amravati   444802             95          1378          1473
#
# [195 rows x 5 columns]

# %%
df_maharashtra['pin_multi_district_flag'] = (
    df_maharashtra.groupby('pincode')['district']
      .transform('nunique') > 1
)

# %%
pin_district_map = (
    df_maharashtra[df_maharashtra['pin_multi_district_flag']]
    .groupby('pincode')['district_clean']
    .unique()
    .reset_index()
)

# %%
file_path='pin_district_map.xlsx'
pin_district_map.to_excel(file_path, index=False)

# %%
df_maharashtra['pin_multi_district_flag'].value_counts()
# Out:
# pin_multi_district_flag
# False    90029
# True     72214
# Name: count, dtype: int64

# %%
df_maharashtra['total_enroll']=df_maharashtra['demo_age_5_17']+df_maharashtra['demo_age_17_']
df_maharashtra
# Out:
#                date        state  district  pincode  demo_age_5_17  \
# 15       01-03-2025  Maharashtra    Nashik   422305             13
# 29       01-03-2025  Maharashtra   Jalgaon   425310             30
# 84       01-03-2025  Maharashtra    Nagpur   440007             10
# 110      01-03-2025  Maharashtra    Mumbai   400097             28
# 152      01-03-2025  Maharashtra   Solapur   413214             22
# ...             ...          ...       ...      ...            ...
# 2065029  28-12-2025  Maharashtra  Yavatmal   445206              2
# 2065030  28-12-2025  Maharashtra  Yavatmal   445211              0
# 2065031  28-12-2025  Maharashtra  Yavatmal   445215              0
# 2065032  28-12-2025  Maharashtra  Yavatmal   445216              0
# 2065033  28-12-2025  Maharashtra  Yavatmal   445304              1
#
#          demo_age_17_  new_date  state_clean district_clean  \
# 15                227  20250301  Maharashtra         Nashik
# ...

# %%
df_maharashtra['month']=df_maharashtra['new_date'].astype(str).str[4:6]
df_maharashtra
# Out:
#                date        state  district  pincode  demo_age_5_17  \
# 15       01-03-2025  Maharashtra    Nashik   422305             13
# 29       01-03-2025  Maharashtra   Jalgaon   425310             30
# 84       01-03-2025  Maharashtra    Nagpur   440007             10
# 110      01-03-2025  Maharashtra    Mumbai   400097             28
# 152      01-03-2025  Maharashtra   Solapur   413214             22
# ...             ...          ...       ...      ...            ...
# 2065029  28-12-2025  Maharashtra  Yavatmal   445206              2
# 2065030  28-12-2025  Maharashtra  Yavatmal   445211              0
# 2065031  28-12-2025  Maharashtra  Yavatmal   445215              0
# 2065032  28-12-2025  Maharashtra  Yavatmal   445216              0
# 2065033  28-12-2025  Maharashtra  Yavatmal   445304              1
#
#          demo_age_17_  new_date  state_clean district_clean  \
# 15                227  20250301  Maharashtra         Nashik
# ...

# %%
df_maharashtra_cleaned=df_maharashtra.drop(columns=['date','district','state'], axis=1)
df_maharashtra_cleaned
# Out:
#          pincode  demo_age_5_17  demo_age_17_  new_date  state_clean  \
# 15        422305             13           227  20250301  Maharashtra
# 29        425310             30           685  20250301  Maharashtra
# 84        440007             10            57  20250301  Maharashtra
# 110       400097             28           675  20250301  Maharashtra
# 152       413214             22           331  20250301  Maharashtra
# ...          ...            ...           ...       ...          ...
# 2065029   445206              2            18  20251228  Maharashtra
# 2065030   445211              0             1  20251228  Maharashtra
# 2065031   445215              0            24  20251228  Maharashtra
# 2065032   445216              0             1  20251228  Maharashtra
# 2065033   445304              1            23  20251228  Maharashtra
#
#         district_clean  pin_multi_district_flag  total_enroll month
# 15              Nashik                    False           240    03
# ...

# %%
df_maharashtra_dist_level=df_maharashtra_cleaned.groupby('district_clean')[['demo_age_5_17','demo_age_17_','total_enroll']].sum()
df_maharashtra_dist_level.shape
# Out:
# (36, 3)

# %%
df_maharashtra_dist_level
# Out:
#                            demo_age_5_17  demo_age_17_  total_enroll
# district_clean
# Ahmednagar                          8714        226966        235680
# Akola                               2889         59193         62082
# Amravati                            5974         90217         96191
# Beed                                9049        174020        183069
# Bhandara                            1658         36236         37894
# Buldhana                            4522        132591        137113
# Chandrapur                          3249        108822        112071
# Chhatrapati Sambhajinagar          10460        167047        177507
# Dharashiv                           3254        108767        112021
# Dhule                               3645         58263         61908
# Gadchiroli                          2371         50327         52698
# Gondia                              3509         63092         66601
# ...

# %%
df_maharashtra_dist_level.sort_values('total_enroll', ascending=False).reset_index()
# df_maharashtra_dist_level.to_excel("df_maharashtra_dist_level.xlsx")
# Out:
#                district_clean  demo_age_5_17  demo_age_17_  total_enroll
# 0                       Thane          36090        411164        447254
# 1                        Pune          32644        405834        438478
# 2                     Solapur           7735        257811        265546
# 3                      Nashik          14785        231315        246100
# 4                      Nanded           7187        229602        236789
# 5                  Ahmednagar           8714        226966        235680
# 6             Mumbai Suburban          19920        176698        196618
# 7                    Yavatmal           5104        191008        196112
# 8                      Mumbai          12044        175314        187358
# 9                        Beed           9049        174020        183069
# 10  Chhatrapati Sambhajinagar          10460        167047        177507
# 11                     Nagpur          13044        145858        158902
# ...

# %%
df_maharashtra_dist_level1=df_maharashtra_dist_level.head(10)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 8))   # width, height in inches
sns.lineplot(data=df_maharashtra_dist_level1[['demo_age_5_17','demo_age_17_']])
plt.show()

# %%
df_maharashtra_pincode_level=df_maharashtra_cleaned.groupby('pincode')[['demo_age_5_17','demo_age_17_','total_enroll']].sum()
df_maharashtra_pincode_level.shape
# Out:
# (1609, 3)

# %%
df_maharashtra_pincode_level.sort_values('total_enroll', ascending=False).reset_index()
# df_maharashtra_dist_level.to_excel("df_maharashtra_dist_level.xlsx")
# Out:
#       pincode  demo_age_5_17  demo_age_17_  total_enroll
# 0      421302           4964         56402         61366
# 1      401107           4369         44259         48628
# 2      431001           4321         39027         43348
# 3      400612           5796         36852         42648
# 4      431122           3292         34840         38132
# ...       ...            ...           ...           ...
# 1604   416144              0             1             1
# 1605   400041              0             1             1
# 1606   416423              0             1             1
# 1607   444125              0             1             1
# 1608   411081              0             1             1
#
# [1609 rows x 4 columns]

# %%
df_maharashtra_pincode_level
# Out:
#          demo_age_5_17  demo_age_17_  total_enroll
# pincode
# 400001              43           619           662
# 400002              72          1961          2033
# 400003             165          1956          2121
# 400004             122          1779          1901
# 400005             265          2545          2810
# ...                ...           ...           ...
# 445307              55           960          1015
# 445308              70          4314          4384
# 445323              55          3371          3426
# 445401              65          2713          2778
# 445402             201          8370          8571
#
# [1609 rows x 3 columns]

# %%
df_maharashtra_pincode_level.sort_values('total_enroll', ascending=False).reset_index().tail(20)
# Out:
#       pincode  demo_age_5_17  demo_age_17_  total_enroll
# 1589   411069              0            10            10
# 1590   444911              0             9             9
# 1591   401608              0             7             7
# 1592   400039              0             6             6
# 1593   402208              0             5             5
# 1594   415630              0             5             5
# 1595   400085              0             4             4
# 1596   425327              1             2             3
# 1597   410517              0             3             3
# 1598   431154              0             3             3
# 1599   425121              0             2             2
# 1600   400073              0             2             2
# 1601   400613              0             2             2
# 1602   416550              0             2             2
# 1603   444512              0             2             2
# ...

# %%
df_maharashtra_pincode_level1=df_maharashtra_pincode_level.head(10)
df_maharashtra_pincode_level1
# Out:
#          demo_age_5_17  demo_age_17_  total_enroll
# pincode
# 400001              43           619           662
# 400002              72          1961          2033
# 400003             165          1956          2121
# 400004             122          1779          1901
# 400005             265          2545          2810
# 400006              32           709           741
# 400007              42           627           669
# 400008             865          7215          8080
# 400009             166          1812          1978
# 400010             261          2948          3209

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 8))   # width, height in inches
sns.lineplot(data=df_maharashtra_pincode_level1[['demo_age_5_17','demo_age_17_']])
plt.show()

# %%
maharashtra_month_enroll_trend=df_maharashtra_cleaned.groupby('month')[['demo_age_5_17','demo_age_17_','total_enroll']].sum()
maharashtra_month_enroll_trend
# Out:
#        demo_age_5_17  demo_age_17_  total_enroll
# month
# 03             45650        666552        712202
# 04              6110         56326         62436
# 05              9959         80772         90731
# 06             12811         94291        107102
# 07             15732        117649        133381
# 09             40705        326707        367412
# 10             27192        694698        721890
# 11             52842       1873287       1926129
# 12             62321        870999        933320

# %%
maharashtra_month_enroll_trend.to_excel("df_maharashtra_month_level.xlsx")

# %%
sns.lineplot(data=maharashtra_month_enroll_trend)
# Out:
# <Axes: xlabel='month'>
